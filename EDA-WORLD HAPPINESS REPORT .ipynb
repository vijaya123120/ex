# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(10,7)
plt.rcParams['figure.facecolor']='#FFE5B4'

# %%
data=pd.read_csv('world-happiness-report-2021.csv')

# %%
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
data_columns=['Country name','Regional indicator','Ladder score','Logged GDP per capita','Social support','Healthy life expectancy',
             'Freedom to make life choices','Generosity','Perceptions of corruption']

# %%
data=data[data_columns].copy()

# %%
data
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
happy_df = data.rename(columns={'Country name':'Country_name',
                                'Regional indicator':'Regional_indicator',
                                'Ladder score':'Happiness_score',
                                'Logged GDP per capita':'Logged_GDP_per_capita',
                                'Social support':'Social_support',
                                'Healthy life expectancy':'Healthy_life_expectancy',
                                'Freedom to make life choices':'Freedom_to_make_life_choices',
                                'Perceptions of corruption':'Perceptions_of_corruption'})

# %%
happy_df
# Out:
#     Country_name  Regional_indicator  Happiness_score  Logged_GDP_per_capita  \
# 0        Finland      Western Europe            7.842                 10.775
# 1        Denmark      Western Europe            7.620                 10.933
# 2    Switzerland      Western Europe            7.571                 11.117
# 3        Iceland      Western Europe            7.554                 10.878
# 4    Netherlands      Western Europe            7.464                 10.932
# ..           ...                 ...              ...                    ...
# 144      Lesotho  Sub-Saharan Africa            3.512                  7.926
# 145     Botswana  Sub-Saharan Africa            3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa            3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa            3.145                  7.943
# 148  Afghanistan          South Asia            2.523                  7.695
#
# ...

# %%
happy_df.isnull().sum()
# Out:
# Country_name                    0
# Regional_indicator              0
# Happiness_score                 0
# Logged_GDP_per_capita           0
# Social_support                  0
# Healthy_life_expectancy         0
# Freedom_to_make_life_choices    0
# Generosity                      0
# Perceptions_of_corruption       0
# dtype: int64

# %%
#plot b/w happiness and GDP 
plt.rcParams['figure.figsize']=(15,7)
plt.title('plot between Happiness score and GDP')
sns.scatterplot(x=happy_df.Happiness_score,y=happy_df.Logged_GDP_per_capita,hue=happy_df.Regional_indicator,s=150)
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happiness Score')
plt.ylabel('GDP_per_capita')
plt.show()

# %%
GDP_Region=happy_df.groupby('Regional_indicator')['Logged_GDP_per_capita'].sum()

# %%
GDP_Region
# Out:
# Regional_indicator
# Central and Eastern Europe            171.854
# Commonwealth of Independent States    112.822
# East Asia                              62.206
# Latin America and Caribbean           187.400
# Middle East and North Africa          164.324
# North America and ANZ                  43.238
# South Asia                             60.778
# Southeast Asia                         84.793
# Sub-Saharan Africa                    290.707
# Western Europe                        227.277
# Name: Logged_GDP_per_capita, dtype: float64

# %%
GDP_Region.plot.pie(autopct='%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
plt.show()

# %%
#Total countries
Total_country=happy_df.groupby('Regional_indicator')['Country_name'].count()

# %%
Total_country
# Out:
# Regional_indicator
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# East Asia                              6
# Latin America and Caribbean           20
# Middle East and North Africa          17
# North America and ANZ                  4
# South Asia                             7
# Southeast Asia                         9
# Sub-Saharan Africa                    36
# Western Europe                        21
# Name: Country_name, dtype: int64

# %%
#correlation
cor=happy_df.corr(method='pearson')
f,ax=plt.subplots(figsize=(10,5))
sns.heatmap(cor,ax=ax,cmap='YlGnBu')
plt.show()

# %%
#corrpution in region
corruption=happy_df.groupby('Regional_indicator')[['Perceptions_of_corruption']].mean()

# %%
corruption
# Out:
#                                     Perceptions_of_corruption
# Regional_indicator
# Central and Eastern Europe                           0.850529
# Commonwealth of Independent States                   0.725083
# East Asia                                            0.683333
# Latin America and Caribbean                          0.792600
# Middle East and North Africa                         0.762235
# North America and ANZ                                0.449250
# South Asia                                           0.797429
# Southeast Asia                                       0.709111
# Sub-Saharan Africa                                   0.765944
# Western Europe                                       0.523095

# %%
plt.rcParams['figure.figsize']=(12,8)
plt.title('perception of corruption in various Regions')
plt.xlabel('Regions',fontsize=15)
plt.ylabel('corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index,corruption.Perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
#Top happiest countries
top_10_happy = happy_df.nlargest(10, 'Happiness_score')
bottom_10_happy = happy_df.nsmallest(10, 'Happiness_score')


num_bars = len(top_10_happy)
color_palette = sns.color_palette('Set3', num_bars)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot the top 10 happiest countries
ax1.bar(top_10_happy['Country_name'], top_10_happy['Healthy_life_expectancy'], color=color_palette)
ax1.set_xticklabels(top_10_happy['Country_name'], rotation=90)
ax1.set_xlabel('Country')
ax1.set_ylabel('Healthy Life Expectancy')
ax1.set_title('Top 10 Happiest Countries')

# Plot the bottom 10 happiest countries
ax2.bar(bottom_10_happy['Country_name'], bottom_10_happy['Healthy_life_expectancy'], color=color_palette)
ax2.set_xticklabels(bottom_10_happy['Country_name'], rotation=90)
ax2.set_xlabel('Country')
ax2.set_ylabel('Healthy Life Expectancy')
ax2.set_title('Bottom 10 Happiest Countries')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\vijaya\AppData\Local\Temp/ipykernel_11308/4096456524.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(top_10_happy['Country_name'], rotation=90)
# C:\Users\vijaya\AppData\Local\Temp/ipykernel_11308/4096456524.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(bottom_10_happy['Country_name'], rotation=90)

# %%
happy_df
# Out:
#     Country_name  Regional_indicator  Happiness_score  Logged_GDP_per_capita  \
# 0        Finland      Western Europe            7.842                 10.775
# 1        Denmark      Western Europe            7.620                 10.933
# 2    Switzerland      Western Europe            7.571                 11.117
# 3        Iceland      Western Europe            7.554                 10.878
# 4    Netherlands      Western Europe            7.464                 10.932
# ..           ...                 ...              ...                    ...
# 144      Lesotho  Sub-Saharan Africa            3.512                  7.926
# 145     Botswana  Sub-Saharan Africa            3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa            3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa            3.145                  7.943
# 148  Afghanistan          South Asia            2.523                  7.695
#
# ...

# %%
#happiness score v/s freedom to make life choices
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.Freedom_to_make_life_choices,y=happy_df.Happiness_score,hue=happy_df.Regional_indicator,s=150)
plt.legend(loc='upper left',fontsize='12')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness score')
plt.show()

# %%
country=happy_df.sort_values(by='Perceptions_of_corruption').head(10)
plt.rcParams['figure.figsize']=(12,6)
plt.title('Countries with most perception of corruption')
plt.xlabel('country',fontsize=13)
plt.ylabel('Corruption Index',fontsize=13)
plt.xticks(rotation=30,ha='right')
plt.bar(country.Country_name,country.Perceptions_of_corruption)
plt.show()

# %%
#corruption vs happiness
plt.rcParams['figure.figsize']=[15,7]
sns.scatterplot(x=happy_df.Happiness_score,y=happy_df.Perceptions_of_corruption,hue=happy_df.Regional_indicator,s=150)
plt.legend(loc='upper left',fontsize='12')

plt.show()
